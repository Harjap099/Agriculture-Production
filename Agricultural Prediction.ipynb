# %% [markdown]
# # Agricultural production in India.

# %% [markdown]
#  First, we need to import the required libraries.

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pwd           #Setting up the file path
# Out:
# '/home/harjap/Main Workspace/WorkSpace/AnacondaFiles'

# %%
df = pd.read_csv('apy.csv')                      #Importing the dataset in jupyter notebook.

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
# State_Name       246091 non-null object
# District_Name    246091 non-null object
# Crop_Year        246091 non-null int64
# Season           246091 non-null object
# Crop             246091 non-null object
# Area             246091 non-null float64
# Production       246091 non-null float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# ...

# %%
df.dropna()                                     #Droping the NaN- Values.
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 5       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 6       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 7       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 8       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 9       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 10      Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# 11      Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# ...

# %% [markdown]
# Using .dropna() function to drop the null or empty valaus in the dataset.

# %%
a = df.groupby('Crop_Year')
a.mean()
# Out:
#                    Area    Production
# Crop_Year
# 1997       26038.324081  9.565489e+04
# 1998       14479.153906  5.051002e+05
# 1999       12678.074790  5.141563e+05
# 2000       12102.612169  5.454466e+05
# 2001       12371.499489  5.587561e+05
# 2002        9463.680476  4.616973e+05
# 2003        9954.769395  4.580305e+05
# 2004       11891.933465  5.801135e+05
# 2005       11822.333236  5.829232e+05
# 2006       11913.672644  6.059404e+05
# 2007       10513.848637  4.735951e+05
# 2008       11768.527148  5.303793e+05
# 2009       11738.077997  5.426817e+05
# 2010       12557.355280  4.484613e+05
# 2011       10918.140920  1.016907e+06
# 2012       11369.858240  6.093255e+05
# 2013       10368.125223  9.453179e+05
# 2014       10549.306622  7.896237e+05
# 2015        8187.362989  1.233997e+04

# %% [markdown]
# Here, the above groupby table is used for calulating mean values according to the column 'Crop Year'.

# %%
df.groupby('Crop_Year')['Production'].mean().plot(kind = 'pie',figsize=(35,12),title= 'Maximum Crop Area State Wise')

# %% [markdown]
# This 'Piechart' can be used to represent or visualize graph for 'State_Name' and 'Area'.

# %%
df.groupby('State_Name')['Area'].mean().plot(kind = 'bar',figsize=(35,12),title= 'Maximum Crop Area State Wise')

# %% [markdown]
# The above representation of the Pie-Chart can also be done using this 'Bar Graph'.

# %%
df.groupby('Crop_Year')['Production'].mean().plot(kind = 'bar',figsize=(35,12),title= 'Maximum Crop Production Year Wise')

# %% [markdown]
# Here, this graph shows us the overall production Year- Wise.

# %%
df.groupby('State_Name')['Production'].mean().plot(kind = 'bar',figsize=(35,12),title= 'Maximum Crop Production State Wise')

# %% [markdown]
# Now, we apply Gradient Decent using one Independent and one Dependent Variable.

# %%
x_data= df.dropna().loc[: ,['Crop_Year']].values
sample= len(x_data)
x_ones= np.ones((sample, 1))
x_final= np.append(x_ones , x_data, axis =1)
y_final = df.dropna().loc[: ,['Production']].values

# %% [markdown]
# In this, case we need Y_Final as 'Production' as we need to predict it w.r.t 'Crop_Year'.

# %%
new_beta=np.random.rand(2,1)

# %%
for i in range(13):
    y_pred= np.dot(x_final , new_beta)
    derivative = -2*(np.dot(np.transpose(y_final- y_pred),x_final))/sample
    new_beta = new_beta-(0.1*derivative.T)
    cost= ((y_final-y_pred)**2)/sample

# %%
y_pred= int(input('Enter the Year for which you want the prediction to occur? '))
y_cap= y_pred*new_beta[1]+ new_beta[0]
# Out:
# Enter the Year for which you want the prediction to occur? 2022

# %%
y_cap
# Out:
# array([3.41717294e+82])

# %% [markdown]
# This shows the required Predicted value in case of Production
